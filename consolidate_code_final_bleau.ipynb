# %%
def tagset_mapping(source_tag):
  tagset_mapping1= {'NN':'NN','NNP':'NN','NST':'NN','NNC':'NN',
                 'PR':'PR','PRP':'PR','PRF':'PR','PRL':'PR','PRC':'PR','PRQ':'PR','PRI':'PR',
                 'DM':'DM','DMD':'DM','DMQ':'DM','DMI':'DM',
                 'VM':'VM','VAUX':'VM',
                 'JJ':'JJ',
                 'RB':'RB',
                 'PSP':'PSP',
                 'CC':'CC','CCD':'CC','CCS':'CC',
                 'RP':'RP','RPD':'RP','INJ':'RP','INTF':'RP','NEG':'RP',
                 'QT':'QT','QTF':'QT','QTC':'QT','QTO':'QT',
                 'RD':'RD','RDF':'RD','SYM':'RD','PUNC':'RD','UNK':'RD','ECH':'RD','X':'RD'
                                          }
  for k,v in tagset_mapping1.items():
    if(source_tag==k):
      source_tag=tagset_mapping1[k]
  return source_tag

# %%
t1="/content/transformer_base_output_datset_2.txt"
t2="//content/tr2.txt"
with open(t1, "r") as f1, open(t2, "a+") as f2:
 for l1 in f1.readlines():
     if(l1!="\n"):
        f2.write(l1)

# %%
import spacy
nlp = spacy.load('en')
filename='/content/drive/My Drive/englis.txt'

# %%
lines = [line.rstrip('\n') for line in open(filename)]

# %%
print(lines)
# Out:
# ['Speaking on the occasion, the President said that the role of the Government in public life would always remain paramount.', 'Speaking on the occasion, the President said the achievements of the National Innovation Foundation (NIF) over the last decade, based on the voluntary contribution of thousands of Honey Bee Network members are creditable.', 'Thursday is the day specially sacred to the goddess of wealth, Lakshmi.', 'The old woman realised that she had beaten a god.', 'This is of immense help to students seeking admission in various streams in colleges', 'The Environmental Clearance process is in place to ensure efficiency in resource use for large projects.', 'And everyone of them will come to Him singly on the Day of Judgment.', 'I SAW A GIRL WITH A TELESCOP', 'I AM GOING TO FISH A FISH', 'The dog is faster than the cat', 'It \'s all right Mum, ?- "I\' m taking a slice out with me."', "Create resource '% s' - failed with HTTP status% d (% s)", 'She believes, “Yes, this is it
# ...

# %% [markdown]
#  **ENGLISH POS AND DEP**

# %%
file_out=open("/content/drive/My Drive/eng_pos.txt","w")
file_out1=open("/content/drive/My Drive/eng_dep.txt","w")
for each_line in lines:
  doc = nlp(each_line)
  #print(doc)
  #print(each_line)
  for token in doc:
    file_out.write(str(tagset_mapping(token.tag_)))
    file_out.write(" ")
    file_out1.write(str(token.dep_))
    file_out1.write(" ")
  file_out.write("\n")
  file_out1.write("\n")
file_out.close()
file_out1.close()

# %% [markdown]
#  **REFERNCE POS AND DEP**

# %%
nlp1 = spacy.load('/content/drive/My Drive/hindi_lang/model-final')

file1="/content/ref.txt"
file2="/content/ref_pos2.txt"
file3="/content/ref_dep2.txt"
lines = [line.rstrip('\n') for line in open(file1)]

file_out=open(file2,"w")
file_out1=open(file3,"w")
for each_line in lines:
    doc = nlp1(each_line)
    #print(each_line)
    for token in doc:
        file_out.write(str(token.tag_))
        file_out.write(" ")
        file_out1.write(str(token.dep_))
        file_out1.write(" ")
    file_out.write("\n")
    file_out1.write("\n")
file_out.close()
file_out1.close()

# %% [markdown]
# **TRANSLATED POS AND DEP**

# %%
file4="/content/tran.txt"
file5="/content/translated_pos2.txt"
file6="/content/translated_dep2.txt"
lines = [line.rstrip('\n') for line in open(file4)]

file_out=open(file5,"w")
file_out1=open(file6,"w")
for each_line in lines:
    doc = nlp1(each_line)
    #print(each_line)
    for token in doc:
        file_out.write(str(token.tag_))
        file_out.write(" ")
        file_out1.write(str(token.dep_))
        file_out1.write(" ")
    file_out.write("\n")
    file_out1.write("\n")
file_out.close()
file_out1.close()

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# **TEXT BLEU**

# %%
from nltk import word_tokenize
from nltk.translate.bleu_score import sentence_bleu
translated_file = "/content/tr.txt"
reference_file = "/content/re.txt"
f5 = open('/content/o1.txt', "a+")
with open(translated_file, "r") as f1, open(reference_file, "r") as f2:
  lines1 = [line.rstrip('\n') for line in f1]
  #print(lines1)
  lines2 = [line.rstrip('\n') for line in f2]
  #print(lines2)
  for l1,l2 in zip(lines1,lines2):
    tokens_ref=[word_tokenize(l2)]
    tokens_translate=word_tokenize(l1)
    score = sentence_bleu(tokens_ref, tokens_translate, weights=(0.25, 0.25, 0.25, 0.25))
    f5.write(str(score)+'\n')
f5.close()
# Out:
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 4-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 3-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
from nltk import word_tokenize
from nltk.translate.bleu_score import sentence_bleu
reference_english = "/content/drive/My Drive/englis.txt"
translated_file = "/content/drive/My Drive/t2.txt"
reference_file = "/content/drive/My Drive/r1.txt"
f5 = open('/content/drive/My Drive/o2.txt', "a+")
with open(translated_file, "r") as f1, open(reference_file, "r") as f2, open(reference_english, "r") as f6:
  lines1 = [line.rstrip('\n') for line in f1]
  #print(lines1)
  lines2 = [line.rstrip('\n') for line in f2]
  #print(lines2)
  for l1,l2 in zip(lines1,lines2):
    tokens_ref=[word_tokenize(l2)]
    tokens_translate=word_tokenize(l1)
    score = sentence_bleu(tokens_ref, tokens_translate, weights=(0.25, 0.25, 0.25, 0.25))
    f5.write(str(score)+'\n')
f5.close()
# Out:
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 3-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 4-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
from nltk import word_tokenize
from nltk.translate.bleu_score import sentence_bleu
reference_english = "/content/drive/My Drive/englis.txt"
translated_file = "/content/drive/My Drive/t3.txt"
reference_file = "/content/drive/My Drive/r1.txt"
f5 = open('/content/drive/My Drive/o3.txt', "a+")
with open(translated_file, "r") as f1, open(reference_file, "r") as f2, open(reference_english, "r") as f6:
  lines1 = [line.rstrip('\n') for line in f1]
  #print(lines1)
  lines2 = [line.rstrip('\n') for line in f2]
  #print(lines2)
  for l1,l2 in zip(lines1,lines2):
    tokens_ref=[word_tokenize(l2)]
    tokens_translate=word_tokenize(l1)
    score = sentence_bleu(tokens_ref, tokens_translate, weights=(0.25, 0.25, 0.25, 0.25))
    f5.write(str(score)+'\n')
f5.close()
# Out:
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 3-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 4-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
from nltk import word_tokenize
from nltk.translate.bleu_score import sentence_bleu
reference_english = "/content/drive/My Drive/englis.txt"
translated_file = "/content/drive/My Drive/t4.txt"
reference_file = "/content/drive/My Drive/r1.txt"
f5 = open('/content/drive/My Drive/o4.txt', "a+")
with open(translated_file, "r") as f1, open(reference_file, "r") as f2, open(reference_english, "r") as f6:
  lines1 = [line.rstrip('\n') for line in f1]
  #print(lines1)
  lines2 = [line.rstrip('\n') for line in f2]
  #print(lines2)
  for l1,l2 in zip(lines1,lines2):
    tokens_ref=[word_tokenize(l2)]
    tokens_translate=word_tokenize(l1)
    score = sentence_bleu(tokens_ref, tokens_translate, weights=(0.25, 0.25, 0.25, 0.25))
    f5.write(str(score)+'\n')
f5.close()
# Out:
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 3-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 4-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# **POS BLEU**

# %%
from nltk import word_tokenize
from nltk.translate.bleu_score import sentence_bleu
translated_file = "/content/translated_pos2.txt"
reference_file = "/content/ref_pos2.txt"
f5 = open('/content/simple_output_pos2.txt', "a+")
with open(translated_file, "r") as f1, open(reference_file, "r") as f2:
  lines1 = [line.rstrip('\n') for line in f1]
  #print(lines1)
  lines2 = [line.rstrip('\n') for line in f2]
  #print(lines2)
  for l1,l2 in zip(lines1,lines2):
    tokens_ref=[word_tokenize(l2)]
    tokens_translate=word_tokenize(l1)
    score = sentence_bleu(tokens_ref, tokens_translate, weights=(0.25, 0.25, 0.25, 0.25))
    f5.write(str(score)+'\n')
f5.close()

# %% [markdown]
# **DEP BLEU**

# %%
translated_file = "/content/translated_dep2.txt"
reference_file = "/content/ref_dep2.txt"
f5 = open('/content/output_dep2.txt', "a+")
with open(translated_file, "r") as f1, open(reference_file, "r") as f2:
  lines1 = [line.rstrip('\n') for line in f1]
  #print(lines1)
  lines2 = [line.rstrip('\n') for line in f2]
  #print(lines2)
  for l1,l2 in zip(lines1,lines2):
    tokens_ref=[word_tokenize(l2)]
    tokens_translate=word_tokenize(l1)
    score = sentence_bleu(tokens_ref, tokens_translate, weights=(0.25, 0.25, 0.25, 0.25))
    f5.write(str(score)+'\n')
f5.close()
# Out:
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 4-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %% [markdown]
# **FLEXIBLEU**

# %%
translated_dep_file = "/content/drive/My Drive/output_dep2.txt"
translated_pos_file = "/content/drive/My Drive/simple_output_pos2.txt.txt"
translated_bleu_file = "/content/drive/My Drive/output11.txt"
f5 = open('/content/drive/My Drive/FLEXIBLEU.txt', "a+")
flex=0.0
with open(translated_bleu_file, "r") as f1, open(translated_pos_file, "r") as f2,  open(translated_dep_file, "r") as f6:
  lines1 = [line.rstrip('\n') for line in f1]
  lines2 = [line.rstrip('\n') for line in f2]
  lines3 = [line.rstrip('\n') for line in f6]
  for l1,l2,l3 in zip(lines1,lines2,lines3):
    flex=0.0
    flex=((((6*float(l2))+(2*float(l3)))/2)+(2*float(l1)))/10
    f5.write(str(flex)+'\n')
f5.close()
